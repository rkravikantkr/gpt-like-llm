# %% [markdown]
# ## What is PyTorch ?
# - deep learning library
# - three main components 1) Tensor library, 2) Automatic differentiaton engine, 3) Deep learning library
# ```
# tensor library as a fundamental building block for computing, automatic differentiation for model optimization, and deep learning utility functions, making it easier to implement and train deep neural network models.
# ```
# -  accelerates computation on GPUs, thus providing a seamless switch between CPUs and GPUs.
# - LLMs are often referred to as AI models. However, LLMs are also a type
# of deep neural network, and PyTorch is a deep learning library.
#
# ```
# Deep learning is a subcategory of machine learning focused on implementing deep neural networks. Machine learning is a subcategory of AI that is concerned with algorithms that learn from data. AI is the broader concept of machines being able to perform tasks that typically require human intelligence.
# ```

# %%
# !pip install torch

# %%
# !pip install numpy

# %%
import torch
print(torch.backends.mps.is_available())

# %% [markdown]
# ### Tensors
# - mathematical concepts that generalizes vectors and matrices to potentially higher dimensions.
# - scalar, vector, matrices are Tensors of order of 0, 1, and 2 respectively.
# - tensors hold multidimensional data, each dimension represents a different feature

# %%
import torch 
tensor0d = torch.tensor(1)
tensor1d = torch.tensor([1,2,3])
tensor2d = torch.tensor([[1,2], [3,4]])

tensor3d = torch.tensor([[[1,2], [3,4]],
                         [[5,6],[7,8]]])

# print(tensor0d)
# print(tensor1d)
# print(tensor2d)
# print(tensor3d)
print(tensor3d.shape)
print(tensor3d.view(1,2,4))   # reshaping a tensor  similar to .reshape()

# print(tensor0d.dtype)
# print(tensor1d.dtype)
